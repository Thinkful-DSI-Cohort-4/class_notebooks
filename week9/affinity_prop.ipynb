# %%
# %reload_ext nb_black

# %%
import pandas as pd
import numpy as np

from scipy.spatial.distance import pdist, squareform

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import AffinityPropagation

from tqdm.notebook import tqdm

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
data_url = "https://docs.google.com/spreadsheets/d/198EG3tckqzD1uOKSYxAY62i5v_0LIZQMgzaIae6u1vo/export?format=csv"
zillow = pd.read_csv(data_url)

# Drop columns with higher than 20% missing values
drop = zillow.columns[zillow.isna().mean() > 0.2]
zillow = zillow.drop(columns=drop)

# Drop remaining missing values
zillow = zillow.dropna()

# Manually selected features to use
keep_cols = [
    # How much
    "taxamount",
    # How big
    "garagetotalsqft",
    "lotsizesquarefeet",
    "numberofstories",
    #     "poolcnt",  # dropped because 0 variance
    "roomcnt",
]

zillow = zillow[keep_cols]
# zillow = zillow.sample(1500, random_state=1337)

# %%
scaler = StandardScaler()
scaled = scaler.fit_transform(zillow)

# %%
sim_mat = -squareform(pdist(scaled))
sim_mat.min() - 1
# Out:
# -43.07119774057715

# %%
clst = AffinityPropagation(affinity="precomputed", damping=0.99, verbose=1)
clst.fit(sim_mat)
# Out:
# Converged after 15 iterations.
# AffinityPropagation(affinity='precomputed', convergence_iter=15, copy=True,
#                     damping=0.99, max_iter=200, preference=None, verbose=1)

# %%
cluster_df = zillow.copy()
cluster_df["label"] = clst.labels_
cluster_df["label"] = "Cluster " + cluster_df["label"].astype(str)
# sns.pairplot(cluster_df, hue="label")
# plt.show()

# %%
cluster_sizes = cluster_df["label"].value_counts().reset_index()
cluster_sizes.columns = ["label", "count"]

# %%
exemplar_idxs = clst.cluster_centers_indices_
exemplars = cluster_df.iloc[exemplar_idxs, :]

exemplars = pd.merge(exemplars, cluster_sizes, on="label")

exemplars.sort_values("taxamount").style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow0_col1 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow0_col2 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow0_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow0_col6 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow1_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow1_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow1_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow1_col4 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow1_col6 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow2_col0 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow2_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow2_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow2_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow2_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow2_col6 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow3_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow3_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow3_col2 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow3_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow3_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow3_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow4_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow4_col1 {
#             background-color:  #f4edf6;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow4_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow4_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow4_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow4_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow5_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow5_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow5_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow5_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow5_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow5_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow6_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow6_col1 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow6_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow6_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow6_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow6_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow7_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow7_col1 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow7_col2 {
#             background-color:  #69a5cc;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow7_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow7_col4 {
#             background-color:  #cacee5;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow7_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow8_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow8_col1 {
#             background-color:  #f4eef6;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow8_col2 {
#             background-color:  #62a2cb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow8_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow8_col4 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow8_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow9_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow9_col1 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow9_col2 {
#             background-color:  #c0c9e2;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow9_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow9_col4 {
#             background-color:  #dbdaeb;
#             color:  #000000;
#         }    #T_0ad8f564_9140_11ea_afa6_a683e7ada4efrow9_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;

# %%
mean_cluster_df = cluster_df.groupby("label").mean()
mean_cluster_df.sort_values("taxamount").style.background_gradient()
# Out:
# <style  type="text/css" >
#     #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow0_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow0_col2 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow0_col3 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow0_col4 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow1_col0 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow1_col1 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow1_col2 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow1_col3 {
#             background-color:  #efe9f3;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow1_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow2_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow2_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow2_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow2_col3 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow2_col4 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow3_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow3_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow3_col2 {
#             background-color:  #ced0e6;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow3_col3 {
#             background-color:  #c4cbe3;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow3_col4 {
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow4_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow4_col1 {
#             background-color:  #e5e1ef;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow4_col2 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow4_col3 {
#             background-color:  #a5bddb;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow4_col4 {
#             background-color:  #e0deed;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow5_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow5_col1 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow5_col2 {
#             background-color:  #02395a;
#             color:  #f1f1f1;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow5_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow5_col4 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow6_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow6_col1 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow6_col2 {
#             background-color:  #fef6fa;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow6_col3 {
#             background-color:  #75a9cf;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow6_col4 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow7_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow7_col1 {
#             background-color:  #f3edf5;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow7_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow7_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow7_col4 {
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow8_col0 {
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow8_col1 {
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow8_col2 {
#             background-color:  #308cbe;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow8_col3 {
#             background-color:  #73a9cf;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow8_col4 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow9_col0 {
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow9_col1 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow9_col2 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow9_col3 {
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow9_col4 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow10_col0 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow10_col1 {
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow10_col2 {
#             background-color:  #faf3f9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow10_col3 {
#             background-color:  #9cb9d9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow10_col4 {
#             background-color:  #d7d6e9;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow11_col0 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow11_col1 {
#             background-color:  #f6eff7;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow11_col2 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow11_col3 {
#             background-color:  #96b6d7;
#             color:  #000000;
#         }    #T_0ae41f20_9140_11ea_afa6_a683e7ada4efrow11_col4 {
#             background-color:  #a8bedc;
#             color:  #0

# %%
scaled_exemplars = pd.DataFrame(scaled[exemplar_idxs, :], columns=zillow.columns)
scaled_exemplars.std()
# Out:
# taxamount            6.906484
# garagetotalsqft      5.916120
# lotsizesquarefeet    7.957650
# numberofstories      0.944576
# roomcnt              1.972318
# dtype: float64

# %%
cluster_df[cluster_df["label"] == "Cluster 4"]
# Out:
#        taxamount  garagetotalsqft  lotsizesquarefeet  numberofstories  \
# 40      29112.50            913.0           435600.0              2.0
# 99      18528.66           1182.0           509788.0              2.0
# 171     45064.24            840.0           512266.0              2.0
# 297     20021.88            687.0           362419.0              1.0
# 441     11305.14            586.0           292723.0              2.0
# 513     26585.76            660.0           255822.0              2.0
# 588      7814.86            614.0           305791.0              2.0
# 635     23980.80           1027.0           275299.0              2.0
# 832     19308.26           1073.0           435600.0              2.0
# 839     17107.26            945.0           309276.0              2.0
# 864     24862.02           1362.0           379844.0              2.0
# 1035    18131.70            745.0           282704.0              2.0
# 1373    21577.84            803.0           435600.0              2.0
# 1432    16434.34            955.0           268765.0              2.0
# 2272    16723.70           1543.0           316246.0              2.0
# 2488    11582.02           1309.0           280527.0              2.0
# 2617    11314.16            907.0           386812.0              2.0
# 2896    23961.80            960.0           422096.0              1.0
# 3913    15358.20            991.0           440392.0              1.0
# 4133    14433.98            932.0           246985.0              2.0
# 4328    12440.34            634.0           272250.0              2.0
# 5954    31222.70           1004.0           422920.0              2.0
# 6420    24044.50           1146.0           279219.0              1.0
# 6649    39763.72           1625.0           345431.0              2.0
# 7722    45179.22           1182.0           357627.0              2.0
# 8378    48190.40           1066.0           407722.0              2.0
# 8871    17869.34            770.0           253955.0              2.0
# 10031   24102.04            986.0           442570.0              2.0
# 10981   29407.56           1111.0           325530.0              2.0
# 13608   14280.38            660.0           336719.0              1.0
# 14050   31640.58            820.0           439956.0              2.0
# 14197   12490.92            900.0           350222.0              2.0
#
#        roomcnt      label
# 40          11  Cluster 4
# 99          13  Cluster 4
# 171         11  Cluster 4
# 297         12  Cluster 4
# 441          9  Cluster 4
# 513         12  Cluster 4
# 588         11  Cluster 4
# 635         13  Cluster 4
# 832         11  Cluster 4
# 839          9  Cluster 4
# 864         11  Cluster 4
# 1035        10  Cluster 4
# 1373        11  Cluster 4
# 1432        10  Cluster 4
# 2272        13  Cluster 4
# 2488         9  Cluster 4
# 2617        10  Cluster 4
# 2896        10  Cluster 4
# 3913        11  Cluster 4
# 4133        12  Cluster 4
# 4328         9  Cluster 4
# 5954        11  Cluster 4
# 6420        11  Cluster 4
# 6649        10  Cluster 4
# 7722        14  Cluster 4
# 8378        14  Cluster 4
# 8871        10  Cluster 4
# 10031       11  Cluster 4
# 10981       11  Cluster 4
# 13608       13  Cluster 4
# 14050       10  Cluster 4
# 14197        9  Cluster 4

# %%
cluster_df[cluster_df["label"] == "Cluster 0"]
# Out:
#    taxamount  garagetotalsqft  lotsizesquarefeet  numberofstories  roomcnt  \
# 0  283062.46           4000.0           709157.0              2.0       21
#
#        label
# 0  Cluster 0
